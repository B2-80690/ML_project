# %%
import pandas as pd
import numpy as np
import json

# %%
data = pd.read_csv("movieData1.csv")
# nameOfMovies = data["Name_of_movie"] 
# nameOfDirector = data["Name_of_director"]
# listOfGenre = data["List_of_genre"]
# discriptionOfMovie = data["Discription_of_movie"]
# languageOfMovie = data["Language_of_move"]
# countryOfOrigin = data["Country_of_origin"]
# nameOfCast = data["Names_of_Cast"]

# %%
data
# Out:
#       Unnamed: 0                Name_of_movie            Name_of_director  \
# 0              0  Monarch: Legacy of Monsters                Matt Shakman
# 1              1                        Andor              Benjamin Caron
# 2              2     Avatar: The Way of Water               James Cameron
# 3              3                The Equalizer               Antoine Fuqua
# 4              4             The Last Kingdom           Edward Bazalgette
# ...          ...                          ...                         ...
# 1109         245                The 400 Blows           François Truffaut
# 1110         246                      Persona              Ingmar Bergman
# 1111         247                Life of Brian                 Terry Jones
# 1112         248                      Aladdin   Ron Clements, John Musker
# 1113         249           Dances with Wolves               Kevin Costner
#
#                              List_of_genre  \
# ...

# %%
# here i am copying the original data
copyind = data
copyind
# Out:
#       Unnamed: 0                Name_of_movie            Name_of_director  \
# 0              0  Monarch: Legacy of Monsters                Matt Shakman
# 1              1                        Andor              Benjamin Caron
# 2              2     Avatar: The Way of Water               James Cameron
# 3              3                The Equalizer               Antoine Fuqua
# 4              4             The Last Kingdom           Edward Bazalgette
# ...          ...                          ...                         ...
# 1109         245                The 400 Blows           François Truffaut
# 1110         246                      Persona              Ingmar Bergman
# 1111         247                Life of Brian                 Terry Jones
# 1112         248                      Aladdin   Ron Clements, John Musker
# 1113         249           Dances with Wolves               Kevin Costner
#
#                              List_of_genre  \
# ...

# %%
df=copyind.iloc[:,1:]
df
# Out:
#                     Name_of_movie            Name_of_director  \
# 0     Monarch: Legacy of Monsters                Matt Shakman
# 1                           Andor              Benjamin Caron
# 2        Avatar: The Way of Water               James Cameron
# 3                   The Equalizer               Antoine Fuqua
# 4                The Last Kingdom           Edward Bazalgette
# ...                           ...                         ...
# 1109                The 400 Blows           François Truffaut
# 1110                      Persona              Ingmar Bergman
# 1111                Life of Brian                 Terry Jones
# 1112                      Aladdin   Ron Clements, John Musker
# 1113           Dances with Wolves               Kevin Costner
#
#                              List_of_genre  \
# 0          ["Action","Adventure","Sci-Fi"]
# 1         ['Action', 'Adventure', 'Drama']
# 2       ['Action', 'Adventure', 'Fantasy']
# ...

# %%
df=df.dropna()

# %%
Discription = df["Names_of_Cast"]
movie = df["Name_of_movie"]
count = 0;
for movie in movie:
    print(movie)
# Out:
# Monarch: Legacy of Monsters
# Andor
# Avatar: The Way of Water
# The Equalizer
# The Last Kingdom
# S.W.A.T.
# Kingdom of Heaven
# Halloween Kills
# Onimusha
# The Family Business
# The Pacific
# Smallville
# Avengers: Endgame
# Jurassic Park
# Cobra Kai
# Suicide Squad
# Heat
# Transformers: Rise of the Beasts
# Banshee
# Star Trek: Voyager
# Squid Game
# The Night Agent
# The Fall Guy
# The Gentlemen
# The Fifth Element
# Star Wars: The Clone Wars
# The Crow
# Chicago P.D.
# Star Trek: Deep Space Nine
# Hawaii Five-0
# Star Trek
# Stargate SG-1
# War for the Planet of the Apes
# The Matrix
# Who Is Erin Carter?
# Leon
# John Wick
# Captain Laserhawk: A Blood Dragon Remix
# Person of Interest
# From Dusk Till Dawn
# The Worst Evil
# Arcane
# Sicario
# The Mummy
# 24
# Barry
# Helluva Boss
# Boudica
# Ballerina
# Hypnotic
# Spider-Man
# Scott Pilgrim vs. the World
# Arrow
# The Lord of the Rings: The Return of the King
# No Time to Die
# Sultan of Delhi
# Warrior
# Freddy vs. Jason
# ...
