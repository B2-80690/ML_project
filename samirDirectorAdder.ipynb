# %%
import pandas as pd
import numpy as np
import json

# %%
with open("all_new_data_by_only-Devika_collected.json", "r") as file:
    data = json.load(file)

# %%
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#                  Name_of_movie    Name_of_director  \
# 0  Monarch: Legacy of Monsters                None
# 1                        Andor                None
# 2     Avatar: The Way of Water       James Cameron
# 3                The Equalizer       Antoine Fuqua
# 4             The Last Kingdom                None
# 5                     S.W.A.T.                None
# 6            Kingdom of Heaven        Ridley Scott
# 7              Halloween Kills  David Gordon Green
# 8                     Onimusha                None
# 9          The Family Business                None
#
#                   List_of_genre  \
# 0                            []
# 1    [Action, Adventure, Drama]
# 2  [Action, Adventure, Fantasy]
# 3     [Action, Crime, Thriller]
# 4      [Action, Drama, History]
# 5    [Action, Adventure, Crime]
# 6    [Action, Adventure, Drama]
# 7    [Action, Horror, Thriller]
# 8                            []
# 9                            []
#
# ...

# %%
# all the requared value which are need to be filled
List_of_moviesName = df["Name_of_movie"]
missingDirectorName = df["Name_of_director"]
List_of_genre = df["List_of_genre"]
List_of_Language_of_move = df["Language_of_move"]
List_of_Names_of_Cast = df["Names_of_Cast"]

# %%
# // now i want to find the index where name of director is missing

missingDirectorName = df["Name_of_director"]
indexcesOfMissingDirectorName = list()
# indexcessOfMoviesOfMissingDirector = list()

for i in range(len(missingDirectorName)):
    if(missingDirectorName[i] == None):
       indexcesOfMissingDirectorName.append(i)

# %%
# here i have printed those movies whose direcotor is missin

# for i in indexcesOfMissingDirectorName:
#     print(List_of_moviesName[i] )

# %%
with open("missingDirectorNames.text","r") as file:
    new = file.read()

# %%
# after the 249 you have to break it
names_of_director = list()
data = new.split("\n")
count = 0;
for i in data:
    new_data = i.split(":")
    # print(len(new_data))
    # print(i)
    count+= 1
    # print(count)
    if(count == 250):
        break
    # here i have finded actual director names     
    # print(new_data[1])
    names_of_director.append(new_data[1])

# %%
# here i have got the names of all directors and appended to the original serise where movie name were none and 
# director name was none

counter = 0;
for val in range(len(List_of_moviesName)):
    # print(List_of_moviesName[val] , " ", missingDirectorName[val] )
    if(List_of_moviesName[val] != None and missingDirectorName[val] == None):
        missingDirectorName[val] = names_of_director[counter]
        counter+= 1
        # print(counter)
# Out:
# /tmp/ipykernel_3151998/1081034668.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missingDirectorName[val] = names_of_director[counter]
# /tmp/ipykernel_3151998/1081034668.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   missingDirectorName[val] = names_of_director[counter]
# /tmp/ipykernel_3151998/1081034668.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# now read the genor files

with open("samir163.text" , "r") as file:
    an = file.read()

# %%
# Monarch: Legacy of Monsters == ["Action","Adventure","Sci-Fi"]
# Onimusha == ["Animation","Action","Adventure"]
# The Family Business == ["Action","Crime","Drama"]

listOfMovieNamesWhoseGenreIsMissingFoundBYsplit = list()
listOfGenreFoundBySplit = list()

c = 0
an = an.split("\n")
# print(an)
for i in range(len(an)):
    li = an[i].split("==")
    # for v in range(len(li)):
    c += 1;
    if c == 164:
        break;
    listOfMovieNamesWhoseGenreIsMissingFoundBYsplit.append(li[0])
    listOfGenreFoundBySplit.append(li[1])
   
      
        
 

# li = an[0].split("==")
# print(li[1])

# %%
# now add the genre to those movies whose movie name we have 
# now i have to assigne the genres to the movies;
pointertomovies =0;
for i in range(len(List_of_moviesName)):
    # print(movie)
    if(List_of_moviesName[i] == listOfMovieNamesWhoseGenreIsMissingFoundBYsplit[pointertomovies].strip()):
        # print(movie)
        # now here i have to assigne the genre to these movies
        List_of_genre[i] = listOfGenreFoundBySplit[pointertomovies]
        pointertomovies += 1;
       
       
       
    
    
    if (List_of_moviesName[i] is None ):
        pointertomovies += 1
    if(pointertomovies == 163):
        break
# Out:
# /tmp/ipykernel_3151998/4007114168.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_of_genre[i] = listOfGenreFoundBySplit[pointertomovies]
# /tmp/ipykernel_3151998/4007114168.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_of_genre[i] = listOfGenreFoundBySplit[pointertomovies]
# /tmp/ipykernel_3151998/4007114168.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
List_of_genre = df["List_of_genre"]
List_of_moviesName = df["Name_of_movie"]

# %%
missing_genre_index = list()
missing_genre_nameOfMovies = list();

for index in range(len(List_of_genre)):
    if(len(List_of_genre[index]) == 0):
        missing_genre_index.append(index)
        missing_genre_nameOfMovies.append(index)
        
        

# for i in List_of_genre:
#     if(len(i) == 0):
#         missing_genre_index.append(i)
#         missing_genre_nameOfMovies.append(i)

# %%
# now work on the second data fram which is scrapped sepratedly
with open("all_new_data_sam+Devika_collected.json", "r") as file:
    second = json.load(file)

# %%
secondDf = pd.DataFrame(second)


NameOfMoviesSecondDf = secondDf["Name_of_movie"]
NameOfMovieDirectorSecondDf = secondDf["Name_of_director"]
NameOfMoviesGenreSecondDf = secondDf["List_of_genre"]

# %%
secondDf
# Out:
#                 Name_of_movie      Name_of_director  \
# 0    The Shawshank Redemption        Frank Darabont
# 1               The Godfather  Francis Ford Coppola
# 2             The Dark Knight     Christopher Nolan
# 3       The Godfather Part II  Francis Ford Coppola
# 4                12 Angry Men          Sidney Lumet
# ..                        ...                   ...
# 245             The 400 Blows     François Truffaut
# 246                   Persona        Ingmar Bergman
# 247             Life of Brian           Terry Jones
# 248                   Aladdin                  None
# 249        Dances with Wolves         Kevin Costner
#
#                       List_of_genre  \
# 0                           [Drama]
# 1                    [Crime, Drama]
# 2            [Action, Crime, Drama]
# 3                    [Crime, Drama]
# 4                    [Crime, Drama]
# ..                              ...
# 245                  [Crime, Drama]
# 246               [Drama, Thriller]
# ...

# %%
with open("SecondDirectors.text","r") as f:
    secondDirector = f.read()


with open("SecondGenre.text","r") as secFile:
    secondGenre = secFile.read()

# %%
SecondDirectorList = secondDirector.split("\n")
SecondGenreList = secondGenre.split("\n")
secondSplitedMovieNamesForDirectors = list()
secondSplitedDirectorNames = list()
secondSplitedNameOfMoviesForGenre = list()
secondSplitedGenre = list()

# secondSplitedMovieNamesForGenres = list()

# %%
counterPointer = 0
for val in SecondDirectorList:
    if(counterPointer == 26):
        break
    secondSplitedMovieNamesForDirectors.append(val.split(";")[0])
    secondSplitedDirectorNames.append(val.split(";")[1])    
    counterPointer += 1
    # print(counterPointer)
    # print(val.split(";")[1])
  
    # print(val.split(";")[0])

# %%
counterforgenre = 0;
for val in SecondGenreList:
    if counterforgenre == 27:
        break
        
   
    secondSplitedNameOfMoviesForGenre.append(val.split("==")[0].strip())
    secondSplitedGenre.append(val.split("==")[1])
    counterforgenre += 1

# %%
# here i have assigned the director names to the movies where it was missing
count = 0;
indexSecondDf = 0
for i in range(len(NameOfMoviesSecondDf)):

      if count == 26:
          break
      if NameOfMoviesSecondDf[i] == secondSplitedMovieNamesForDirectors[indexSecondDf].strip():
          # now i have to give the director name
          NameOfMovieDirectorSecondDf[i] = secondSplitedDirectorNames[indexSecondDf]          
          count += 1;         
          indexSecondDf += 1
# Out:
# /tmp/ipykernel_3151998/1025046897.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NameOfMovieDirectorSecondDf[i] = secondSplitedDirectorNames[indexSecondDf]
# /tmp/ipykernel_3151998/1025046897.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NameOfMovieDirectorSecondDf[i] = secondSplitedDirectorNames[indexSecondDf]
# /tmp/ipykernel_3151998/1025046897.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# now i have to assigne the genre to the movies where they are missing
count = 0;
indexSecondDf = 0
for i in range(len(NameOfMoviesSecondDf)):

      if count == 27:
          break
      if NameOfMoviesSecondDf[i] == secondSplitedNameOfMoviesForGenre[indexSecondDf].strip():
          # now i have to give the genre to the moves name
           
          NameOfMoviesGenreSecondDf[i]  = secondSplitedGenre[indexSecondDf]
          # print(NameOfMoviesSecondDf[i])
          # print(NameOfMoviesGenreSecondDf[i])
          
          # print(secondSplitedNameOfMoviesForGenre[indexSecondDf])
          # print(count)
          count += 1;         
          indexSecondDf += 1
# Out:
# /tmp/ipykernel_3151998/87057975.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NameOfMoviesGenreSecondDf[i]  = secondSplitedGenre[indexSecondDf]
# /tmp/ipykernel_3151998/87057975.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NameOfMoviesGenreSecondDf[i]  = secondSplitedGenre[indexSecondDf]
# /tmp/ipykernel_3151998/87057975.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# here i am adding the names of cast where cast is missing

# castName = df["Names_of_Cast"]

with open("missingCastList.text","r") as F:
    Data = F.read()

# print(Data)
# now make the seprate list of movienames and castlist
nameOfMoviesWhoIsMissingCast = list()
castOfMoviesWhoWhereMissing = list()
#step one split it with new line
count = 0
Data  = Data.split("\n")
for i in range(len(Data)):
    if count == 180:
        break
    M = Data[i].split("==")[0].strip()
    C = Data[i].split("==")[1].strip()
    count += 1
    nameOfMoviesWhoIsMissingCast.append(M)
    castOfMoviesWhoWhereMissing.append(C)

# %%
# now i am going to assign the valus where cast is missing

List_of_Names_of_Cast
pointer = 0;
for i in range(len(List_of_moviesName)):
    if List_of_moviesName[i] is None:
       print("hi")
    elif  List_of_moviesName[i] == nameOfMoviesWhoIsMissingCast[pointer] :
        # now assigne the values to the actual
        List_of_Names_of_Cast[i] = castOfMoviesWhoWhereMissing[pointer]
        pointer += 1
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# /tmp/ipykernel_3151998/3262123997.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_of_Names_of_Cast[i] = castOfMoviesWhoWhereMissing[pointer]
# /tmp/ipykernel_3151998/3262123997.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_of_Names_of_Cast[i] = castOfMoviesWhoWhereMissing[pointer]
# /tmp/ipykernel_3151998/3262123997.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# now make whole data fram of all the two and saving it to the csv into the movieData.csv

wholeDataframe = [df , secondDf]

result = pd.concat(wholeDataframe)
result.to_csv("movieData1.csv")

# %%
# here i have founded where the language of movies is missing and name of those movies


# counter = 0
# for lang in range(len(List_of_Language_of_move)):
#      if List_of_Language_of_move[lang] is None:
#          counter += 1
#          print(List_of_moviesName[lang])
#          print(List_of_genre[lang])

# print(counter)

# %%
# Out:
#                    Name_of_movie            Name_of_director  \
# 0    Monarch: Legacy of Monsters                Matt Shakman
# 1                          Andor              Benjamin Caron
# 2       Avatar: The Way of Water               James Cameron
# 3                  The Equalizer               Antoine Fuqua
# 4               The Last Kingdom           Edward Bazalgette
# ..                           ...                         ...
# 245                The 400 Blows           François Truffaut
# 246                      Persona              Ingmar Bergman
# 247                Life of Brian                 Terry Jones
# 248                      Aladdin   Ron Clements, John Musker
# 249           Dances with Wolves               Kevin Costner
#
#                         List_of_genre  \
# 0     ["Action","Adventure","Sci-Fi"]
# 1          [Action, Adventure, Drama]
# 2        [Action, Adventure, Fantasy]
# 3           [Action, Crime, Thriller]
# ...

# %%
# after the 249 you have to break it
