# %%
import pandas as pd

# %%
data = pd.read_json("./all_new_data_by_only-Devika_collected.json")

df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#                  Name_of_movie Name_of_director                 List_of_genre  \
# 0  Monarch: Legacy of Monsters             None                            []
# 1                        Andor             None    [Action, Adventure, Drama]
# 2     Avatar: The Way of Water    James Cameron  [Action, Adventure, Fantasy]
# 3                The Equalizer    Antoine Fuqua     [Action, Crime, Thriller]
# 4             The Last Kingdom             None      [Action, Drama, History]
#
#                                 Discription_of_movie     Run_time_in_min  \
# 0  Set after the battle between Godzilla and the ...                   0
# 1  Prequel series to Star Wars' 'Rogue One'. In a...          40 minutes
# 2  Jake Sully lives with his newfound family form...  3 hours 12 minutes
# 3  A man who believes he has put his mysterious p...  2 hours 12 minutes
# 4  As Alfred the Great defends his kingdom from N...              1 hour
#
#                        Language_of_move  \
# ...
